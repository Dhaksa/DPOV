# %%
from roboflow import Roboflow
rf = Roboflow(api_key="MwuNnjPktvGiGeyTCFvT")
project = rf.workspace("dhaksana-e11fm").project("pallet-detection-qanxs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

custom_data_yaml="C:\\Users\\dhaks\\Downloads\\Pallet detection\\pallet\\Pallet-Detection-2\\data.yaml"  # path to your custom data yaml file

results=model.train(data=custom_data_yaml, epochs=50,imgsz=640)  # train the model

validation_results = model.val(data=custom_data_yaml)  # validate the model on the validation set
# Out:
# New https://pypi.org/project/ultralytics/8.3.124 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.121  Python-3.10.0 torch-2.7.0+cpu CPU (13th Gen Intel Core(TM) i5-13450HX)
# ...

# %%
from ultralytics import YOLO
import cv2

# Load your trained model
model = YOLO("C:\\Users\\dhaks\\Downloads\\Pallet detection\\best.pt")  # Adjust path as needed

# Open webcam (0 is the default camera. Change it if you have multiple cameras)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 inference on the frame
    results = model.predict(source=frame, imgsz=640, conf=0.25)

    # Draw results on frame
    annotated_frame = results[0].plot()

    # Display the annotated frame
    cv2.imshow("YOLOv8 Real-Time Detection", annotated_frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 objects, 551.1ms
# Speed: 4.1ms preprocess, 551.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 364.6ms
# Speed: 2.2ms preprocess, 364.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 397.9ms
# Speed: 2.2ms preprocess, 397.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 361.3ms
# Speed: 1.9ms preprocess, 361.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 350.3ms
# Speed: 1.8ms preprocess, 350.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 370.3ms
# Speed: 2.1ms preprocess, 370.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 349.1ms
# Speed: 1.9ms preprocess, 349.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 467.3ms
# ...
