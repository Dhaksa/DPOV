# %%
from ultralytics import YOLO
import cv2

# Load your trained model
model = YOLO("C:\\Users\\dhaks\Downloads\\Pallet detection\\best.pt")  # Adjust path as needed

# Open webcam (0 is the default camera. Change it if you have multiple cameras)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 inference on the frame
    results = model.predict(source=frame, imgsz=640, conf=0.25)

    # Draw results on frame
    annotated_frame = results[0].plot()

    # Display the annotated frame
    cv2.imshow("YOLOv8 Real-Time Detection", annotated_frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 objectss, 935.1ms
# Speed: 11.4ms preprocess, 935.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 685.6ms
# Speed: 2.1ms preprocess, 685.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 678.0ms
# Speed: 1.8ms preprocess, 678.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 804.6ms
# Speed: 1.6ms preprocess, 804.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 969.8ms
# Speed: 2.8ms preprocess, 969.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 935.8ms
# Speed: 3.9ms preprocess, 935.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 1085.7ms
# Speed: 4.1ms preprocess, 1085.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 objects, 1087.6ms
# ...
